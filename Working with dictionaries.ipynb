# %%
import pymongo
import requests
import json

# %%
from pymongo import MongoClient

DB_Connection_String = "mongodb://weather_alerts_noaa:3rEdq0kG5JYtBwzS@cluster0-shard-00-00.g7wmg.mongodb.net:27017,cluster0-shard-00-01.g7wmg.mongodb.net:27017,cluster0-shard-00-02.g7wmg.mongodb.net:27017/weather_db?ssl=true&replicaSet=atlas-qznk27-shard-0&authSource=admin&retryWrites=true&w=majority"
client = MongoClient(DB_Connection_String)
#conn = client[""]

# %%
db = client["weather_db"]

alerts = db["noaa_alerts_1"]

# %%
url = "https://api.weather.gov/alerts/active?status=actual&message_type=alert&urgency=Expected&severity=Severe&certainty=Likely"

payload={}
headers = {
  'token': 'wXHJVRtlobSPNPyOksaRVqTzrwWXkksj'
}

response = requests.request("GET", url, headers=headers, data=payload)

response = response.json()

# %%
type(response)
# Out:
# dict

# %%
response
# Out:
# {'@context': ['https://geojson.org/geojson-ld/geojson-context.jsonld',
#   {'@version': '1.1',
#    'wx': 'https://api.weather.gov/ontology#',
#    '@vocab': 'https://api.weather.gov/ontology#'}],
#  'type': 'FeatureCollection',
#  'features': [{'id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#    'type': 'Feature',
#    'geometry': None,
#    'properties': {'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#     '@type': 'wx:Alert',
#     'id': 'urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#     'areaDesc': 'Sitkinak to Castle Cape',
#     'geocode': {'SAME': ['058150'], 'UGC': ['PKZ150']},
#     'affectedZones': ['https://api.weather.gov/zones/forecast/PKZ150'],
#     'references': [],
#     'sent': '2021-11-20T15:56:00-09:00',
#     'effective': '2021-11-20T15:56:00-09:00',
#     'onset': '2021-11-21T05:00:00-09:00',
# ...

# %%
new_response = { key:value for (key,value) in response.items() if key == 'features'}

# %%
new_response
# Out:
# {'features': [{'id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#    'type': 'Feature',
#    'geometry': None,
#    'properties': {'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#     '@type': 'wx:Alert',
#     'id': 'urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#     'areaDesc': 'Sitkinak to Castle Cape',
#     'geocode': {'SAME': ['058150'], 'UGC': ['PKZ150']},
#     'affectedZones': ['https://api.weather.gov/zones/forecast/PKZ150'],
#     'references': [],
#     'sent': '2021-11-20T15:56:00-09:00',
#     'effective': '2021-11-20T15:56:00-09:00',
#     'onset': '2021-11-21T05:00:00-09:00',
#     'expires': '2021-11-21T04:45:00-09:00',
#     'ends': '2021-11-21T17:00:00-09:00',
#     'status': 'Actual',
#     'messageType': 'Alert',
#     'category': 'Met',
#     'severity': 'Severe',
#     'certainty': 'Likely',
# ...

# %%
#new_response1 = { key:value for (key,value) in new_response.items() if key == 'id'}
get_nested(new_response,'features','geocode')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-92d1fafe3557> in <module>
#       1 #new_response1 = { key:value for (key,value) in new_response.items() if key == 'id'}
# ----> 2 get_nested(new_response,'features','geocode')
#
# NameError: name 'get_nested' is not defined

# %%
new_response1 = new_response['features']

# %%
new_response1
# Out:
# [{'id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#   'type': 'Feature',
#   'geometry': None,
#   'properties': {'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#    '@type': 'wx:Alert',
#    'id': 'urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#    'areaDesc': 'Sitkinak to Castle Cape',
#    'geocode': {'SAME': ['058150'], 'UGC': ['PKZ150']},
#    'affectedZones': ['https://api.weather.gov/zones/forecast/PKZ150'],
#    'references': [],
#    'sent': '2021-11-20T15:56:00-09:00',
#    'effective': '2021-11-20T15:56:00-09:00',
#    'onset': '2021-11-21T05:00:00-09:00',
#    'expires': '2021-11-21T04:45:00-09:00',
#    'ends': '2021-11-21T17:00:00-09:00',
#    'status': 'Actual',
#    'messageType': 'Alert',
#    'category': 'Met',
#    'severity': 'Severe',
#    'certainty': 'Likely',
#    'urgency': 'Expected',
# ...

# %%
type(new_response1)
# Out:
# list

# %%
new_response2 = [d['properties'] for d in new_response1]

# %%
new_response2
# Out:
# [{'@id': 'https://api.weather.gov/alerts/urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#   '@type': 'wx:Alert',
#   'id': 'urn:oid:2.49.0.1.840.0.c24017a7411ff62356829929ca4864307117c7de.002.2',
#   'areaDesc': 'Sitkinak to Castle Cape',
#   'geocode': {'SAME': ['058150'], 'UGC': ['PKZ150']},
#   'affectedZones': ['https://api.weather.gov/zones/forecast/PKZ150'],
#   'references': [],
#   'sent': '2021-11-20T15:56:00-09:00',
#   'effective': '2021-11-20T15:56:00-09:00',
#   'onset': '2021-11-21T05:00:00-09:00',
#   'expires': '2021-11-21T04:45:00-09:00',
#   'ends': '2021-11-21T17:00:00-09:00',
#   'status': 'Actual',
#   'messageType': 'Alert',
#   'category': 'Met',
#   'severity': 'Severe',
#   'certainty': 'Likely',
#   'urgency': 'Expected',
#   'event': 'Heavy Freezing Spray Warning',
#   'sender': 'w-nws.webmaster@noaa.gov',
#   'senderName': 'NWS Anchorage AK',
# ...

# %%
new_response3 = [d['geocode'] for d in new_response2]

# %%
new_response3
# Out:
# [{'SAME': ['058150'], 'UGC': ['PKZ150']},
#  {'SAME': ['058150'], 'UGC': ['PKZ150']},
#  {'SAME': ['058181'], 'UGC': ['PKZ181']},
#  {'SAME': ['058160'], 'UGC': ['PKZ160']},
#  {'SAME': ['058180'], 'UGC': ['PKZ180']},
#  {'SAME': ['058140'], 'UGC': ['PKZ140']},
#  {'SAME': ['058139'], 'UGC': ['PKZ139']},
#  {'SAME': ['058127'], 'UGC': ['PKZ127']},
#  {'SAME': ['058138'], 'UGC': ['PKZ138']},
#  {'SAME': ['058130'], 'UGC': ['PKZ130']},
#  {'SAME': ['058210'], 'UGC': ['PKZ210']},
#  {'SAME': ['056001', '056007'], 'UGC': ['WYZ110']},
#  {'SAME': ['006065', '006071', '006073', '006059'],
#   'UGC': ['CAZ248', 'CAZ255', 'CAZ256', 'CAZ257', 'CAZ265', 'CAZ554']},
#  {'SAME': ['006037', '006111'], 'UGC': ['CAZ246', 'CAZ253', 'CAZ254']},
#  {'SAME': ['006111', '006037'],
#   'UGC': ['CAZ240',
#    'CAZ241',
#    'CAZ244',
#    'CAZ245',
#    'CAZ288',
#    'CAZ547',
#    'CAZ548']},
#  {'SAME': ['058140'], 'UGC': ['PKZ140']},
#  {'SAME': ['058127'], 'UGC': ['PKZ127']},
# ...

# %%
new_response1 = [stu for stu in new_response if stu =='features']

# %%
new_response1
# Out:
# []

# %%
pwd()
# Out:
# 'C:\\Users\\Mithun'
